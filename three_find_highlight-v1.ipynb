# %%
import os
import glob
from math import floor

from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
import soundfile as sf
import librosa

# %%
#Load the NLP model
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('sentence-transformers/sentence-t5-large')  # https://huggingface.co/sentence-transformers/sentence-t5-large

# %%
sound_path = "./sound"
audioset_path = './sound/audioset_files'
highlight_path = './sound/highlights_v1'

alpha = 0.2  # weight for music class

sound_list = sorted(glob.glob(os.path.join(sound_path, "*.wav")))

if not os.path.exists(highlight_path):
    os.mkdir(highlight_path)

# %%
df_list = []  # all info
df_highlight_list = []
for index, row in enumerate(sound_list):
# for index, row in enumerate(sound_list[1:2]):
# for index, row in enumerate(sound_list[0:1]):
    print("{0} {1}".format(index, row))
    filename = os.path.basename(row)
    transcript_file = os.path.join(audioset_path, filename[:-4]+".csv")
    df_curr = pd.read_csv(transcript_file)

    # Music score
    print("...checking audio...")
    score_music = [1.0 if "Music" in row[1] else 0.0 for row in enumerate(df_curr['class_labels'])]
    df_curr['score_music'] = score_music
    
    # find the episode name
    print("...checking texts...")
    episode_name = filename.split('_')[-1][:-4]
    episode_name = episode_name.replace("-", " ")
    # Query based on the file name: "What is about <EPISODE NAME>"
    query = "what is about "+episode_name+"?"
    print("Query: {0}".format(query))
    # Embedding of the query
    query_emb = model.encode(query)

    # Compute the embedding of each paragraph
    texts = []
    for i in range(df_curr.shape[0]):
        texts.append(df_curr.iloc[i]['content'])
    doc_emb = model.encode(texts)
    scores = util.dot_score(query_emb, doc_emb)[0].cpu().tolist()
    df_curr['similarity'] = scores
    df_curr['sound_file'] = filename
    df_list.append(df_curr)
    
    # Total score
    print("...calculating scores...")
    df_curr['total_score'] = alpha*df_curr['score_music'] + (1.0-alpha)*df_curr['similarity']
    
    # Find the largest similarity
    # id_max = df_curr['similarity'].idxmax()
    id_max = df_curr[df_curr['duration']>=20.0]['total_score'].idxmax()  # Need to 20 sec long
    if not id_max:  # if id_max None => use the first segment
        id_max = 0
        
    start_time = df_curr.iloc[id_max]['start_time']
    end_time = df_curr.iloc[id_max]['end_time']
    duration = end_time - start_time
    if duration >= 4.0*60.0:  # 4 min
        end_time = start_time + 4.0*60.0
        duration = 4.0*60.0
    
    df_highlight_list.append({'sound_file': filename, 
                              'id_max': id_max,
                              'score': df_curr.iloc[id_max]['total_score'],
                              'score_text': df_curr.iloc[id_max]['similarity'],
                              'score_music': df_curr.iloc[id_max]['score_music'],
                              'start_time': start_time,
                              'end_time': end_time,
                              'duration': duration,
                              'content': df_curr.iloc[id_max]['content'],
                             })

    samples, samplerate = sf.read(row)
    samples_highlight = samples[floor(start_time*samplerate):floor(end_time*samplerate)]  # assuming mono channel
    highlight_filename = os.path.join(highlight_path, filename)
    sf.write(highlight_filename, samples_highlight, samplerate)
# Out:
# 0 ./sound/99-invisible_matters-of-time.wav
# ...checking audio...
# ...checking texts...
# Query: what is about matters of time?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 1 ./sound/99-invisible_stuff-the-british-stole.wav
# ...checking audio...
# ...checking texts...
# Query: what is about stuff the british stole?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 2 ./sound/a16z_crypto.wav
# ...checking audio...
# ...checking texts...
# Query: what is about crypto?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 3 ./sound/a16z_developers-as-creatives.wav
# ...checking audio...
# ...checking texts...
# Query: what is about developers as creatives?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 4 ./sound/a16z_malaria-vaccine.wav
# ...checking audio...
# ...checking texts...
# Query: what is about malaria vaccine?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 5 ./sound/conan-obrien_cecily-strong.wav
# ...checking audio...
# ...checking texts...
# Query: what is about cecily strong?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 6 ./sound/conan-obrien_joel-mchale.wav
# ...checking audio...
# ...checking texts...
# Query: what is about joel mchale?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 7 ./sound/masters-of-scale_build-the-right-flywheel.wav
# ...checking audio...
# ...checking texts...
# Query: what is about build the right flywheel?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 8 ./sound/masters-of-scale_make-it-epic.wav
# ...checking audio...
# ...checking texts...
# Query: what is about make it epic?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 9 ./sound/masters-of-scale_master-your-emotions.wav
# ...checking audio...
# ...checking texts...
# Query: what is about master your emotions?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 10 ./sound/my-first-million_how-to-build-a-community.wav
# ...checking audio...
# ...checking texts...
# Query: what is about how to build a community?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 11 ./sound/my-first-million_the-secret-to-being-great.wav
# ...checking audio...
# ...checking texts...
# Query: what is about the secret to being great?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 12 ./sound/npr-politics_august-27th.wav
# ...checking audio...
# ...checking texts...
# Query: what is about august 27th?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 13 ./sound/npr-politics_cutting-unemployment.wav
# ...checking audio...
# ...checking texts...
# Query: what is about cutting unemployment?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 14 ./sound/npr-politics_school-mask-ban.wav
# ...checking audio...
# ...checking texts...
# Query: what is about school mask ban?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 15 ./sound/radiolab_dark-side-of-the-earth.wav
# ...checking audio...
# ...checking texts...
# Query: what is about dark side of the earth?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 16 ./sound/radiolab_dinopocalypse-redux.wav
# ...checking audio...
# ...checking texts...
# Query: what is about dinopocalypse redux?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 17 ./sound/the-internet-says-its-true_hidden-village.wav
# ...checking audio...
# ...checking texts...
# Query: what is about hidden village?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 18 ./sound/the-internet-says-its-true_hollywood.wav
# ...checking audio...
# ...checking texts...
# Query: what is about hollywood?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 19 ./sound/this-american-life_essential.wav
# ...checking audio...
# ...checking texts...
# Query: what is about essential?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...
# 20 ./sound/this-american-life_getting-out.wav
# ...checking audio...
# ...checking texts...
# Query: what is about getting out?
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# Ignored unknown kwarg option direction
# ...calculating scores...

# %%
df_highlight = pd.DataFrame(df_highlight_list)

# %%
pd.set_option('display.max_rows', None)
df_highlight
# Out:
#                                         sound_file  id_max     score  \
# 0                 99-invisible_matters-of-time.wav       0  0.845439
# 1         99-invisible_stuff-the-british-stole.wav       0  0.873570
# 2                                  a16z_crypto.wav       0  0.663986
# 3                 a16z_developers-as-creatives.wav      13  0.686931
# 4                         a16z_malaria-vaccine.wav      24  0.880818
# 5                   conan-obrien_cecily-strong.wav      36  0.795365
# 6                     conan-obrien_joel-mchale.wav       1  0.841221
# 7    masters-of-scale_build-the-right-flywheel.wav     110  0.798459
# 8                masters-of-scale_make-it-epic.wav      68  0.820989
# 9        masters-of-scale_master-your-emotions.wav      18  0.860032
# 10   my-first-million_how-to-build-a-community.wav      34  0.648792
# 11  my-first-million_the-secret-to-being-great.wav      60  0.774439
# 12                    npr-politics_august-27th.wav      18  0.802166
# 13           npr-politics_cutting-unemployment.wav      27  0.771516
# 14                npr-politics_school-mask-ban.wav      24  0.816171
# 15             radiolab_dark-side-of-the-earth.wav      35  0.821197
# 16                radiolab_dinopocalypse-redux.wav     103  0.839190
# 17   the-internet-says-its-true_hidden-village.wav       2  0.843748
# 18        the-internet-says-its-true_hollywood.wav       1  0.861437
# 19                this-american-life_essential.wav      75  0.839721
# 20              this-american-life_getting-out.wav      59  0.835693
#
#     score_text  score_music  start_time  end_time  duration  \
# 0     0.806799          1.0        0.40     40.80     40.40
# 1     0.841962          1.0        0.56     32.48     31.92
# 2     0.829982          0.0        0.00    178.48    178.48
# 3     0.858664          0.0      669.68    752.16     82.48
# 4     0.851022          1.0      829.12    953.60    124.48
# 5     0.744206          1.0      462.40    581.20    118.80
# 6     0.801526          1.0       30.16     96.72     66.56
# 7     0.748074          1.0     2600.72   2631.28     30.56
# 8     0.776236          1.0     1488.24   1526.96     38.72
# 9     0.825040          1.0      400.40    492.08     91.68
# 10    0.810990          0.0      854.72   1051.92    197.20
# 11    0.718048          1.0     2218.32   2255.92     37.60
# 12    0.752708          1.0      664.24    693.28     29.04
# 13    0.714395          1.0      746.88    810.80     63.92
# 14    0.770214          1.0      815.76    858.24     42.48
# 15    0.776497          1.0      581.44    658.48     77.04
# 16    0.798988          1.0     1854.32   1881.20     26.88
# 17    0.804685          1.0       79.92    319.92    240.00
# 18    0.826796          1.0       71.28    311.28    240.00
# 19    0.799652          1.0     1888.88   1957.28     68.40
# 20    0.794616          1.0     1227.52   1306.16     78.64
#
#                                               content
# 0   This is ninety nine percent, invisible, I'm Ro...
# 1   This is ninety nine percent, invisible, I'm Ro...
# 2   Welcome to the sixteen seed podcast Zorn today...
# 3   That's a great question so on. I think the ans...
# 4   Well, there are a couple of things to think ab...
# 5   No trust me better put some ice on that thing....
# 6   My name is Sir Joel Mchale and I feel I'm a li...
# 7   There is no one magic bullet when it comes to ...
# 8   If you don't know about the big you project, y...
# 9   I'm Reid, Offffman, CO, founder of Linkedin pa...
# 10  So clablyn is cool because the thing about com...
# 11  I got big rabbin, my Ditty, I'm prevalent. How...
# 12  Wherever you get your podcast right, we are ba...
# 13  That's right. Now, of course, just as you want...
# 14  It seems to me at least looking at the science...
# 15  You thought it could be out there in space. Th...
# 16  We told about the end of the dinosaurs alive a...
# 17  This is one I have not heard about, which is t...
# 18  Thanks Marty, I got this link and I don't know...
# 19  This was a health crisis, doctors, nurses, sur...
# 20  Some of our favorite stories. We've run about ...

# %%
df_all = pd.concat(df_list)

# %%
df_all
# Out:
#      speaker_id                                       class_labels  \
# 0             0                                ['Speech', 'Music']
# 1             1                                         ['Speech']
# 2             2                                         ['Speech']
# 3             3                                         ['Speech']
# 4             4                           ['Speech', 'Beatboxing']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                        ['Silence']
# 8             8                                         ['Speech']
# 9             9                                         ['Speech']
# 10           10    ['Speech', 'Music', 'Percussion', 'Wood block']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                                         ['Speech']
# 16           16                             ['Speech', 'Laughter']
# 17           17                                         ['Speech']
# 18           18                                         ['Speech']
# 19           19                                         ['Speech']
# 20           20                                         ['Speech']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                         ['Speech']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                                         ['Speech']
# 31           31                               ['Speech', 'Hiccup']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                         ['Speech']
# 37           37                                         ['Speech']
# 38           38                                         ['Speech']
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                                         ['Speech']
# 42           42                                         ['Speech']
# 43           43                                         ['Speech']
# 44           44                                         ['Speech']
# 45           45                                         ['Speech']
# 46           46                                         ['Speech']
# 47           47                                         ['Speech']
# 48           48                                         ['Speech']
# 49           49                                         ['Speech']
# 50           50                                         ['Speech']
# 51           51                                         ['Speech']
# 52           52                                         ['Speech']
# 53           53                                         ['Speech']
# 54           54             ['Speech', 'Cough', 'Throat clearing']
# 55           55                                         ['Speech']
# 56           56                                         ['Speech']
# 57           57                                         ['Speech']
# 58           58                                         ['Speech']
# 59           59                        ['Speech', 'Cough', 'Fart']
# 60           60                                         ['Speech']
# 61           61                                         ['Speech']
# 62           62                     ['Speech', 'Music', 'Silence']
# 63           63                                ['Speech', 'Music']
# 64           64                               ['Speech', 'Sneeze']
# 65           65                                         ['Speech']
# 66           66                                         ['Speech']
# 67           67                                         ['Speech']
# 68           68                                         ['Speech']
# 69           69                                         ['Speech']
# 70           70             ['Speech', 'Cough', 'Throat clearing']
# 71           71                                         ['Speech']
# 72           72                                         ['Speech']
# 73           73                                         ['Speech']
# 74           74                                         ['Speech']
# 75           75                                         ['Speech']
# 76           76                                         ['Speech']
# 77           77                                         ['Speech']
# 78           78                                         ['Speech']
# 79           79                                ['Speech', 'Cough']
# 80           80                                         ['Speech']
# 81           81                                         ['Speech']
# 82           82                                         ['Speech']
# 83           83                                         ['Speech']
# 84           84                              ['Speech', 'Silence']
# 85           85                                         ['Speech']
# 86           86                                ['Speech', 'Music']
# 87           87                                ['Speech', 'Music']
# 88           88                                         ['Speech']
# 89           89                                         ['Speech']
# 90           90                                         ['Speech']
# 91           91                                         ['Speech']
# 92           92                                         ['Speech']
# 93           93                                         ['Speech']
# 94           94                                         ['Speech']
# 95           95                                         ['Speech']
# 96           96                                         ['Speech']
# 97           97                                         ['Speech']
# 98           98                                         ['Speech']
# 99           99                                         ['Speech']
# 100         100                                         ['Speech']
# 101         101                                         ['Speech']
# 102         102                                         ['Speech']
# 103         103                                         ['Speech']
# 104         104                                         ['Speech']
# 105         105                                         ['Speech']
# 106         106                                         ['Speech']
# 107         107                                         ['Speech']
# 108         108                                ['Speech', 'Music']
# 109         109  ['Speech', 'Music', 'Mallet percussion', 'Vibr...
# 110         110                                         ['Speech']
# 111         111                                         ['Speech']
# 112         112                                         ['Speech']
# 113         113                                         ['Speech']
# 114         114                                         ['Speech']
# 115         115                                         ['Speech']
# 116         116                                         ['Speech']
# 117         117                                         ['Speech']
# 118         118                                         ['Speech']
# 119         119                                         ['Speech']
# 120         120                                ['Speech', 'Music']
# 121         121                                         ['Speech']
# 122         122                                ['Speech', 'Music']
# 123         123                                         ['Speech']
# 124         124                                         ['Speech']
# 125         125                                         ['Speech']
# 126         126                                                 []
# 127         127                                         ['Speech']
# 128         128                                         ['Speech']
# 129         129                                         ['Speech']
# 130         130                                         ['Speech']
# 131         131                                ['Speech', 'Music']
# 132         132                                ['Speech', 'Music']
# 133         133                                         ['Speech']
# 134         134                                ['Speech', 'Music']
# 135         135                                         ['Speech']
# 136         136                                         ['Speech']
# 137         137                                         ['Speech']
# 138         138                                         ['Speech']
# 139         139                                ['Speech', 'Cough']
# 140         140                                         ['Speech']
# 141         141                                         ['Speech']
# 142         142                                         ['Speech']
# 143         143                                         ['Speech']
# 144         144                                         ['Speech']
# 145         145                                         ['Speech']
# 146         146                                         ['Speech']
# 147         147                                         ['Speech']
# 148         148                                         ['Speech']
# 149         149                                         ['Speech']
# 150         150                                         ['Speech']
# 151         151                                         ['Speech']
# 152         152                                         ['Speech']
# 153         153                                         ['Speech']
# 154         154                                ['Speech', 'Music']
# 155         155                     ['Speech', 'Music', 'Silence']
# 156         156                     ['Speech', 'Music', 'Silence']
# 0             0                    ['Speech', 'Music', 'Doorbell']
# 1             1                                ['Speech', 'Music']
# 2             2                                         ['Speech']
# 3             3                                ['Speech', 'Music']
# 4             4                                ['Speech', 'Music']
# 5             5                                ['Speech', 'Music']
# 6             6                                ['Speech', 'Music']
# 7             7                                ['Speech', 'Music']
# 8             8                                         ['Speech']
# 9             9                                ['Speech', 'Music']
# 10           10                                ['Speech', 'Music']
# 11           11                                         ['Speech']
# 12           12                                ['Speech', 'Music']
# 13           13                                ['Speech', 'Music']
# 14           14                                ['Speech', 'Music']
# 15           15                                         ['Speech']
# 16           16                                         ['Speech']
# 17           17                                         ['Speech']
# 18           18                                                 []
# 19           19                                         ['Speech']
# 20           20                                ['Speech', 'Music']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                ['Speech', 'Music']
# 24           24                                ['Speech', 'Music']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                                         ['Speech']
# 31           31                              ['Speech', 'Silence']
# 32           32  ['Speech', 'Animal', 'Wild animals', 'Bird', '...
# 33           33                                ['Speech', 'Music']
# 34           34                                ['Speech', 'Music']
# 35           35                                ['Speech', 'Music']
# 36           36                                ['Speech', 'Music']
# 37           37                                         ['Speech']
# 38           38  ['Speech', 'Music', 'Wind instrument, woodwind...
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                                ['Speech', 'Music']
# 42           42                                ['Speech', 'Music']
# 43           43                               ['Speech', 'Typing']
# 44           44                                         ['Speech']
# 45           45                                         ['Speech']
# 46           46                                         ['Speech']
# 47           47                                                 []
# 48           48  ['Speech', 'Music', 'Mallet percussion', 'Gloc...
# 49           49                                ['Speech', 'Music']
# 50           50                                ['Speech', 'Music']
# 51           51                                         ['Speech']
# 52           52                                ['Speech', 'Music']
# 53           53                                         ['Speech']
# 54           54                                         ['Speech']
# 55           55                                ['Speech', 'Music']
# 56           56                                         ['Speech']
# 57           57                                         ['Speech']
# 58           58                                         ['Speech']
# 59           59       ['Speech', 'Animal', 'Wild animals', 'Bird']
# 60           60                                ['Speech', 'Music']
# 61           61                                         ['Speech']
# 62           62                                         ['Speech']
# 63           63  ['Speech', 'Music', 'Wind instrument, woodwind...
# 64           64                                ['Speech', 'Music']
# 65           65                                ['Speech', 'Music']
# 66           66                                ['Speech', 'Music']
# 67           67                                ['Speech', 'Music']
# 68           68                                ['Speech', 'Music']
# 69           69                                         ['Speech']
# 70           70                                         ['Speech']
# 71           71                                         ['Speech']
# 72           72                                         ['Speech']
# 73           73                                         ['Speech']
# 74           74                                         ['Speech']
# 75           75                                         ['Speech']
# 76           76                                         ['Speech']
# 77           77                                ['Speech', 'Music']
# 78           78                                ['Speech', 'Music']
# 79           79                                ['Speech', 'Music']
# 80           80                                                 []
# 81           81                                ['Speech', 'Music']
# 82           82                                ['Speech', 'Music']
# 83           83                                         ['Speech']
# 84           84                                         ['Speech']
# 85           85                                         ['Speech']
# 86           86                                ['Speech', 'Music']
# 87           87                                         ['Speech']
# 88           88                                         ['Speech']
# 89           89                                ['Speech', 'Music']
# 90           90                                                 []
# 91           91                                ['Speech', 'Music']
# 92           92                                ['Speech', 'Music']
# 93           93                                ['Speech', 'Music']
# 94           94                                ['Speech', 'Music']
# 95           95                                ['Speech', 'Music']
# 96           96                                         ['Speech']
# 97           97  ['Speech', 'Music', 'Vehicle', 'Rail transport...
# 98           98                                ['Speech', 'Music']
# 99           99                                         ['Speech']
# 100         100                                         ['Speech']
# 101         101                                         ['Speech']
# 102         102                           ['Speech', 'Beatboxing']
# 103         103                                         ['Speech']
# 104         104                                         ['Speech']
# 105         105                                         ['Speech']
# 106         106                                         ['Speech']
# 107         107                                         ['Speech']
# 108         108                        ['Speech', 'Sigh', 'Groan']
# 109         109                                         ['Speech']
# 110         110                                         ['Speech']
# 111         111                                         ['Speech']
# 112         112                                         ['Speech']
# 113         113                                         ['Speech']
# 114         114     ['Speech', 'Music', 'Ding', 'Plop', 'Silence']
# 0             0                                         ['Speech']
# 1             1                                         ['Speech']
# 2             2                                         ['Speech']
# 3             3                                         ['Speech']
# 4             4                                         ['Speech']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                         ['Speech']
# 8             8                                        ['Silence']
# 9             9                                         ['Speech']
# 10           10                                         ['Speech']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                                         ['Speech']
# 16           16                                         ['Speech']
# 17           17                                         ['Speech']
# 18           18                                         ['Speech']
# 19           19                                         ['Speech']
# 20           20                                         ['Speech']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                         ['Speech']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                     ['Speech', 'Chicken, rooster']
# 31           31                                         ['Speech']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                         ['Speech']
# 37           37                                         ['Speech']
# 38           38                                         ['Speech']
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                                         ['Speech']
# 0             0                                         ['Speech']
# 1             1                                         ['Speech']
# 2             2                                         ['Speech']
# 3             3                                         ['Speech']
# 4             4                                         ['Speech']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                         ['Speech']
# 8             8                                         ['Speech']
# 9             9                                         ['Speech']
# 10           10                                         ['Speech']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                                         ['Speech']
# 16           16                                         ['Speech']
# 17           17                                         ['Speech']
# 18           18                                                 []
# 19           19                                         ['Speech']
# 20           20                                 ['Speech', 'Plop']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                         ['Speech']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                                         ['Speech']
# 31           31                                         ['Speech']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                         ['Speech']
# 37           37                                         ['Speech']
# 38           38                                         ['Speech']
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 0             0                   ['Speech', 'Speech synthesizer']
# 1             1                                         ['Speech']
# 2             2                                         ['Speech']
# 3             3                                         ['Speech']
# 4             4                                         ['Speech']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                         ['Speech']
# 8             8                                         ['Speech']
# 9             9                                         ['Speech']
# 10           10                                         ['Speech']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                   ['Speech', 'Speech synthesizer']
# 16           16                                         ['Speech']
# 17           17                   ['Speech', 'Speech synthesizer']
# 18           18                                         ['Speech']
# 19           19                                         ['Speech']
# 20           20                                         ['Speech']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                ['Speech', 'Music']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                                         ['Speech']
# 31           31                                         ['Speech']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                         ['Speech']
# 37           37                                         ['Speech']
# 38           38                                         ['Speech']
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                   ['Speech', 'Speech synthesizer']
# 42           42                   ['Speech', 'Speech synthesizer']
# 43           43                                         ['Speech']
# 44           44                                         ['Speech']
# 45           45                                         ['Speech']
# 46           46                                         ['Speech']
# 47           47                                         ['Speech']
# 48           48                   ['Speech', 'Speech synthesizer']
# 49           49                                         ['Speech']
# 50           50                                         ['Speech']
# 51           51                                         ['Speech']
# 52           52                                         ['Speech']
# 53           53                                         ['Speech']
# 54           54                                         ['Speech']
# 55           55                                         ['Speech']
# 56           56                                         ['Speech']
# 57           57                              ['Speech', 'Silence']
# 58           58                                         ['Speech']
# 59           59                                         ['Speech']
# 60           60                                         ['Speech']
# 61           61                                         ['Speech']
# 62           62                                         ['Speech']
# 0             0  ['Speech', 'Speech synthesizer', 'Music', 'Sil...
# 1             1                                ['Speech', 'Music']
# 2             2                                         ['Speech']
# 3             3  ['Speech', 'Music', 'Musical instrument', 'Plu...
# 4             4                                         ['Speech']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                         ['Speech']
# 8             8                                         ['Speech']
# 9             9                                         ['Speech']
# 10           10                                         ['Speech']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                                         ['Speech']
# 16           16                                         ['Speech']
# 17           17                                         ['Speech']
# 18           18                                         ['Speech']
# 19           19                                         ['Speech']
# 20           20                                         ['Speech']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                         ['Speech']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27                                         ['Speech']
# 28           28                                         ['Speech']
# 29           29                                         ['Speech']
# 30           30                                         ['Speech']
# 31           31                                         ['Speech']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                ['Speech', 'Music']
# 37           37                                         ['Speech']
# 38           38                                         ['Speech']
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                                         ['Speech']
# 42           42                  ['Speech', 'Laughter', 'Snicker']
# 43           43                                         ['Speech']
# 44           44                                         ['Speech']
# 45           45                                         ['Speech']
# 46           46                  ['Speech', 'Laughter', 'Snicker']
# 47           47                                         ['Speech']
# 48           48                                         ['Speech']
# 49           49                                         ['Speech']
# 50           50                                         ['Speech']
# 51           51                                         ['Speech']
# 52           52                                         ['Speech']
# 53           53                                         ['Speech']
# 54           54                                         ['Speech']
# 55           55                                         ['Speech']
# 56           56                                         ['Speech']
# 57           57                                         ['Speech']
# 58           58                             ['Speech', 'Laughter']
# 59           59                                         ['Speech']
# 60           60                                         ['Speech']
# 61           61                                         ['Speech']
# 62           62                                         ['Speech']
# 63           63                                         ['Speech']
# 64           64                                         ['Speech']
# 65           65                                         ['Speech']
# 66           66                                         ['Speech']
# 67           67                                         ['Speech']
# 68           68                                         ['Speech']
# 69           69                                         ['Speech']
# 70           70                                         ['Speech']
# 71           71                             ['Speech', 'Laughter']
# 72           72                                         ['Speech']
# 73           73                                         ['Speech']
# 74           74                                         ['Speech']
# 75           75                                         ['Speech']
# 76           76                                         ['Speech']
# 77           77                                         ['Speech']
# 78           78                                         ['Speech']
# 79           79                                         ['Speech']
# 80           80                                         ['Speech']
# 81           81                                         ['Speech']
# 82           82                                         ['Speech']
# 83           83                                         ['Speech']
# 84           84                                         ['Speech']
# 85           85                                         ['Speech']
# 86           86                                         ['Speech']
# 87           87                                         ['Speech']
# 88           88                                         ['Speech']
# 89           89                                         ['Speech']
# 90           90                                         ['Speech']
# 91           91  ['Speech', 'Music', 'Musical instrument', 'Plu...
# 92           92                                         ['Speech']
# 93           93                                         ['Speech']
# 94           94                                         ['Speech']
# 95           95                                         ['Speech']
# 96           96                                         ['Speech']
# 97           97                             ['Speech', 'Laughter']
# 98           98                  ['Speech', 'Laughter', 'Snicker']
# 99           99                                         ['Speech']
# 100         100                                         ['Speech']
# 101         101                                         ['Speech']
# 102         102                                         ['Speech']
# 103         103                                         ['Speech']
# 104         104                                         ['Speech']
# 105         105                                         ['Speech']
# 106         106                                         ['Speech']
# 107         107                                         ['Speech']
# 108         108                                         ['Speech']
# 109         109                                         ['Speech']
# 110         110                                         ['Speech']
# 111         111                                         ['Speech']
# 112         112                  ['Speech', 'Laughter', 'Snicker']
# 113         113                                         ['Speech']
# 114         114                                         ['Speech']
# 115         115                                         ['Speech']
# 116         116                                         ['Speech']
# 117         117                                         ['Speech']
# 118         118                                                 []
# 119         119                                         ['Speech']
# 120         120                                         ['Speech']
# 121         121                              ['Speech', 'Snicker']
# 122         122                                         ['Speech']
# 123         123                                         ['Speech']
# 124         124                                         ['Speech']
# 125         125                                         ['Speech']
# 126         126                                                 []
# 127         127                                         ['Speech']
# 128         128                                         ['Speech']
# 129         129                                         ['Speech']
# 130         130                                         ['Speech']
# 131         131                                         ['Speech']
# 132         132                                         ['Speech']
# 133         133                                         ['Speech']
# 134         134                                         ['Speech']
# 135         135                                         ['Speech']
# 136         136                                         ['Speech']
# 137         137                                         ['Speech']
# 138         138                                         ['Speech']
# 139         139                                         ['Speech']
# 140         140                                         ['Speech']
# 141         141                                         ['Speech']
# 142         142                                         ['Speech']
# 143         143                                         ['Speech']
# 144         144                                         ['Speech']
# 145         145                                         ['Speech']
# 146         146                                         ['Speech']
# 147         147                                         ['Speech']
# 148         148                                         ['Speech']
# 149         149                                         ['Speech']
# 150         150                                         ['Speech']
# 151         151                                         ['Speech']
# 152         152                                         ['Speech']
# 153         153                                         ['Speech']
# 154         154                                         ['Speech']
# 155         155                                         ['Speech']
# 156         156                                         ['Speech']
# 157         157                                         ['Speech']
# 158         158                                         ['Speech']
# 159         159                                         ['Speech']
# 160         160                                         ['Speech']
# 161         161                                         ['Speech']
# 162         162                                         ['Speech']
# 163         163                                         ['Speech']
# 164         164                  ['Speech', 'Laughter', 'Snicker']
# 165         165                                         ['Speech']
# 166         166  ['Speech', 'Music', 'Musical instrument', 'Plu...
# 167         167                                         ['Speech']
# 168         168                                         ['Speech']
# 169         169                                ['Speech', 'Music']
# 170         170                                                 []
# 171         171                                         ['Speech']
# 172         172                                         ['Speech']
# 173         173                                         ['Speech']
# 174         174                                         ['Speech']
# 175         175                                         ['Speech']
# 176         176                                         ['Speech']
# 177         177                                         ['Speech']
# 178         178                                         ['Speech']
# 179         179                                         ['Speech']
# 180         180                                         ['Speech']
# 181         181                                         ['Speech']
# 182         182                                         ['Speech']
# 183         183                                         ['Speech']
# 184         184                                         ['Speech']
# 185         185                                                 []
# 186         186                                         ['Speech']
# 187         187  ['Speech', 'Laughter', 'Baby laughter', 'Snick...
# 188         188                                         ['Speech']
# 189         189                             ['Speech', 'Laughter']
# 190         190                                         ['Speech']
# 191         191                                         ['Speech']
# 192         192                                         ['Speech']
# 193         193                                         ['Speech']
# 194         194                                         ['Speech']
# 195         195                                         ['Speech']
# 196         196                                         ['Speech']
# 197         197                             ['Speech', 'Laughter']
# 198         198                                         ['Speech']
# 199         199                                         ['Speech']
# 200         200                             ['Speech', 'Laughter']
# 201         201                                         ['Speech']
# 202         202                                         ['Speech']
# 203         203                                         ['Speech']
# 204         204                                         ['Speech']
# 205         205                                         ['Speech']
# 206         206                                         ['Speech']
# 207         207                                         ['Speech']
# 208         208                                         ['Speech']
# 209         209                                         ['Speech']
# 210         210  ['Speech', 'Music', 'Musical instrument', 'Per...
# 0             0  ['Speech', 'Speech synthesizer', 'Music', 'Sil...
# 1             1   ['Speech', 'Music', 'Guitar', 'Acoustic guitar']
# 2             2                                         ['Speech']
# 3             3                                         ['Speech']
# 4             4                                         ['Speech']
# 5             5                                         ['Speech']
# 6             6                                         ['Speech']
# 7             7                                         ['Speech']
# 8             8                                         ['Speech']
# 9             9                                         ['Speech']
# 10           10                                         ['Speech']
# 11           11                                         ['Speech']
# 12           12                                         ['Speech']
# 13           13                                         ['Speech']
# 14           14                                         ['Speech']
# 15           15                                         ['Speech']
# 16           16                                ['Speech', 'Music']
# 17           17                                         ['Speech']
# 18           18                                        ['Silence']
# 19           19                                         ['Speech']
# 20           20                                         ['Speech']
# 21           21                                         ['Speech']
# 22           22                                         ['Speech']
# 23           23                                         ['Speech']
# 24           24                                         ['Speech']
# 25           25                                         ['Speech']
# 26           26                                         ['Speech']
# 27           27  ['Speech', 'Laughter', 'Giggle', 'Belly laugh'...
# 28           28                                         ['Speech']
# 29           29                              ['Speech', 'Snicker']
# 30           30                                         ['Speech']
# 31           31                             ['Speech', 'Laughter']
# 32           32                                         ['Speech']
# 33           33                                         ['Speech']
# 34           34                                         ['Speech']
# 35           35                                         ['Speech']
# 36           36                                         ['Speech']
# 37           37                                         ['Speech']
# 38           38  ['Speech', 'Animal', 'Livestock, farm animals,...
# 39           39                                         ['Speech']
# 40           40                                         ['Speech']
# 41           41                                         ['Speech']
# 42           42                                         ['Speech']
# 43           43                                         ['Speech']
# 44           44                                         ['Speech']
# 45           45                                                 []
# 46           46                                         ['Speech']
# 47           47                                         ['Speech']
# 48           48                                         ['Speech']
# 49           49                                         ['Speech']
# 83     0.691731              this-american-life_getting-out.wav     0.753385
# 84     0.675590              this-american-life_getting-out.wav     0.740472
# 85     0.682782              this-american-life_getting-out.wav     0.546225
# 86     0.641891              this-american-life_getting-out.wav     0.513513
# 87     0.720566              this-american-life_getting-out.wav     0.776453
# 88     0.726102              this-american-life_getting-out.wav     0.780882
# 89     0.709807              this-american-life_getting-out.wav     0.767846
# 90     0.712725              this-american-life_getting-out.wav     0.770180
# 91     0.735191              this-american-life_getting-out.wav     0.788153
# 92     0.717372              this-american-life_getting-out.wav     0.773898
# 93     0.733782              this-american-life_getting-out.wav     0.587026
# 94     0.687378              this-american-life_getting-out.wav     0.549903
# 95     0.712581              this-american-life_getting-out.wav     0.570064
# 96     0.709640              this-american-life_getting-out.wav     0.767712
# 97     0.659684              this-american-life_getting-out.wav     0.727747
# 98     0.695175              this-american-life_getting-out.wav     0.756140
# 99     0.681893              this-american-life_getting-out.wav     0.745515
# 100    0.658151              this-american-life_getting-out.wav     0.726521
# 101    0.730958              this-american-life_getting-out.wav     0.584766
# 102    0.678737              this-american-life_getting-out.wav     0.542990
# 103    0.698377              this-american-life_getting-out.wav     0.558702
# 104    0.775582              this-american-life_getting-out.wav     0.620465
# 105    0.673432              this-american-life_getting-out.wav     0.738745
# 106    0.700082              this-american-life_getting-out.wav     0.560066
# 107    0.684307              this-american-life_getting-out.wav     0.547445
# 108    0.704662              this-american-life_getting-out.wav     0.563730
# 109    0.692502              this-american-life_getting-out.wav     0.554002
# 110    0.699538              this-american-life_getting-out.wav     0.559631
# 111    0.710700              this-american-life_getting-out.wav     0.768560
# 112    0.693784              this-american-life_getting-out.wav     0.755027
# 113    0.694881              this-american-life_getting-out.wav     0.755905
# 114    0.695584              this-american-life_getting-out.wav     0.556467
# 115    0.669447              this-american-life_getting-out.wav     0.535557
# 116    0.751263              this-american-life_getting-out.wav     0.601011
# 117    0.667537              this-american-life_getting-out.wav     0.734030
# 118    0.739447              this-american-life_getting-out.wav     0.591558
# 119    0.617221              this-american-life_getting-out.wav     0.493777
# 120    0.741827              this-american-life_getting-out.wav     0.793462
# 121    0.697450              this-american-life_getting-out.wav     0.757960
# 122    0.703362              this-american-life_getting-out.wav     0.762690

# %%
df_highlight_list[0]
# Out:
# {'sound_file': '99-invisible_matters-of-time.wav',
#  'id_max': 0,
#  'score': 0.8454391002655031,
#  'score_text': 0.8067988753318787,
#  'score_music': 1.0,
#  'start_time': 0.4,
#  'end_time': 40.8,
#  'duration': 40.4,
#  'content': "This is ninety nine percent, invisible, I'm Roman Mars for the most board. We take time for granted. Maybe we don't have enough of it, but at least we know how it works. At least you know most of the time a lot of what we think about time and and how we keep track of. It is relatively recent and some aspects that we take for granted aren't actually all that universal and today we're going to be talking to a few of my young colleagues for a set of many stories about our evolving relationship with time and to get US started. It's Kirk Coolsa, the CO author of the nine hundred percent invisible city, and in our book we wrote about the standardization of time that came with the rise of railroads right and before Standard Times."}
